# %%
import pandas as pd
from PIL import Image, ImageDraw

# %%
df = pd.read_csv("../data/processed/image_planes_num.csv")
plane = pd.read_csv("../data/processed/airplane.csv")

# %%
## create df process
df
# Out:
#      Unnamed: 0                                     index               class  \
# 0             0  014de911-7810-4f7d-8967-3e5402209f4a.jpg            Airplane
# 1             1  014de911-7810-4f7d-8967-3e5402209f4a.jpg  Truncated_airplane
# 2             2  0263270b-e3ee-41dc-aeef-43ff77e66d5b.jpg            Airplane
# 3             3  0263270b-e3ee-41dc-aeef-43ff77e66d5b.jpg  Truncated_airplane
# 4             4  03f84930-e2be-4c19-9afc-0dc26d02538e.jpg            Airplane
# ..          ...                                       ...                 ...
# 152         152  fc1ab8ce-e531-46ed-b74b-0374cd58cf2a.jpg            Airplane
# 153         153  fc1ab8ce-e531-46ed-b74b-0374cd58cf2a.jpg  Truncated_airplane
# 154         154  fc8f9dc5-b6a2-49f3-9bde-1f8ff382ca5f.jpg            Airplane
# 155         155  fc8f9dc5-b6a2-49f3-9bde-1f8ff382ca5f.jpg  Truncated_airplane
# 156         156  fca12ef2-0f65-48d0-a4aa-6bae562f2236.jpg            Airplane
#
#      count
# 0       31
# 1        1
# 2       39
# 3        1
# 4       20
# ..     ...
# 152     56
# 153      2
# 154     28
# 155      1
# 156      8
#
# [157 rows x 4 columns]

# %%
def count_airplanes_in_given_image(image_id):
   # use 014de911-7810-4f7d-8967-3e5402209f4a.jpg as example
   ## Input image_id and compute how many aircraft contains in the given image
   ## return integer
   ## if image_id has no found responding image, throw error: no such image
   df1 = df[df['index']==image_id]
   return df1.loc[: ,"count"].sum()

# %%
count_airplanes_in_given_image("3")
# Out:
# 0

# %%
count_airplanes_in_given_image("014de911-7810-4f7d-8967-3e5402209f4a.jpg")
# Out:
# 32

# %%
def return_images_with_maximum_airplanes(number_of_image):
    withSum = df.groupby(["index"])["count"].sum().reset_index(name="sum")
    df2 = withSum.sort_values(by="sum", ascending=False)
    return df2.head(number_of_image);

# %%
return_images_with_maximum_airplanes(10)
# Out:
#                                         index  sum
# 85   d9399a45-6745-4e59-8903-90640b2ddf9f.jpg   92
# 80   cbd51501-ed0f-411c-b472-df4357cca40c.jpg   88
# 36   56e2d3d3-6b16-401f-a300-847272373df5.jpg   71
# 60   980b5831-43b7-4adb-9e4b-67d6cff3ef68.jpg   67
# 34   54b4e42b-3667-4564-b8fa-c23122ca54d5.jpg   67
# 61   996ba764-cd2a-49c0-9c9f-b166207de0ab.jpg   64
# 50   7635d63c-6b97-4c9c-a7dc-27773d42ed4c.jpg   60
# 100  fc1ab8ce-e531-46ed-b74b-0374cd58cf2a.jpg   58
# 45   696b9320-7dbe-4c28-bd07-7a73e7a28e64.jpg   58
# 21   3e321b8a-9504-45aa-82b4-16158e28e290.jpg   57

# %%
def return_images_with_given_number_of_aircraft(contain_aircraft_number, limit_of_image) -> str:
    ## Input integer of how many aircraft contains 
    # Iterate through all images, find images that contains given number of aircraft
    # display up to 5 of them 
    # return number of these image

    # if no image contain such number of aircraft, return none
    # if input < 0 return error

    """
    a schema based on each image_id
    Image_id  aircraft_number  has_truncated  
                0 or [number]   0 or [truncated]
    """
    withSum = df.groupby(["index"])["count"].sum().reset_index(name="sum")
    df3 = withSum[withSum['sum'] == contain_aircraft_number]
    return df3.head(limit_of_image)

# %%
return_images_with_given_number_of_aircraft(20, 5)
# Out:
#                                        index  sum
# 2   03f84930-e2be-4c19-9afc-0dc26d02538e.jpg   20
# 14  2314c1b5-ec8f-4212-b42f-43365a13fd20.jpg   20
# 17  3463b88d-1e11-4c04-9868-e8c72d510556.jpg   20

# %%
def return_images_with_truncated_aircraft(limit_of_images):
    """ Input 5 would reutrn at most 5 image_id of truncated images
    """
    hasTruncated = df[df['class'] == "Truncated_airplane"]
    df4 = hasTruncated.sort_values(by="count", ascending=False)
    return df4.head(limit_of_images)

# %%
return_images_with_truncated_aircraft(130)
# Out:
#      Unnamed: 0                                     index               class  \
# 101         101  af67041b-f363-47ae-8ddd-f652db3a6bab.jpg  Truncated_airplane
# 65           65  6627e7c7-2fdd-4f3c-965e-b4d73d0a4cc2.jpg  Truncated_airplane
# 98           98  ad36e699-4a1f-4891-b579-6e9ac3e54235.jpg  Truncated_airplane
# 74           74  7635d63c-6b97-4c9c-a7dc-27773d42ed4c.jpg  Truncated_airplane
# 28           28  3e321b8a-9504-45aa-82b4-16158e28e290.jpg  Truncated_airplane
# 62           62  5f726a3d-9876-498f-90c5-9f9efae06c6a.jpg  Truncated_airplane
# 19           19  2314c1b5-ec8f-4212-b42f-43365a13fd20.jpg  Truncated_airplane
# 149         149  f34f05c6-84ce-47d7-ba5c-394d85c86a46.jpg  Truncated_airplane
# 138         138  e9021b38-0b3c-484f-af2c-b36bbf765f85.jpg  Truncated_airplane
# 44           44  4fdabd34-a2fd-4f0a-bb48-01fe043f1499.jpg  Truncated_airplane
# 56           56  57af3c0a-b5ae-4e4f-a7f9-6856be2f80e5.jpg  Truncated_airplane
# 54           54  576827bc-a94a-4611-8820-f3d56e969151.jpg  Truncated_airplane
# 104         104  b3c7c22d-9c71-4ff3-9146-e2f9ab2f9787.jpg  Truncated_airplane
# 116         116  c20b3c21-a6e9-46f7-8536-d4f92574e111.jpg  Truncated_airplane
# 70           70  71252436-5176-40ba-b1ff-73efc251f3c6.jpg  Truncated_airplane
# 67           67  696b9320-7dbe-4c28-bd07-7a73e7a28e64.jpg  Truncated_airplane
# 106         106  b6e9f8fc-3fbd-411a-a1e5-b853e8fbe2ac.jpg  Truncated_airplane
# 12           12  14436c8c-93ec-41af-9fbf-43a5f39f2b98.jpg  Truncated_airplane
# 153         153  fc1ab8ce-e531-46ed-b74b-0374cd58cf2a.jpg  Truncated_airplane
# 136         136  e5416a97-a8ea-415f-928a-e75a5090cd46.jpg  Truncated_airplane
# 140         140  ecfe7982-05e5-435f-824b-e24b6846316e.jpg  Truncated_airplane
# 147         147  ef92f434-c41b-4423-9218-4514c49f00c6.jpg  Truncated_airplane
# 32           32  48ef8e15-a43c-406b-9d3c-e815164b96d1.jpg  Truncated_airplane
# 108         108  b7ab0316-bf02-4266-b44a-cef6417f795c.jpg  Truncated_airplane
# 118         118  c98a544c-4206-4176-b480-35b8bdf5bb14.jpg  Truncated_airplane
# 110         110  babb0ef2-ef2d-4cab-b3e2-230ae2418cdc.jpg  Truncated_airplane
# 113         113  bed88cf9-7887-4bfd-a1d7-b5499ee24f03.jpg  Truncated_airplane
# 123         123  d0c3d270-f23e-4792-bac0-142a9cc8ccc6.jpg  Truncated_airplane
# 130         130  dacabde6-c8a7-475b-ab26-81b4e4dd5977.jpg  Truncated_airplane
# 125         125  d3d2b706-9017-41f4-b57e-469038daa634.jpg  Truncated_airplane
# 127         127  d8873734-016a-4b9d-9b9e-8bc47eb13fef.jpg  Truncated_airplane
# 144         144  eeb978ec-5945-4def-819a-4ea903b17c2d.jpg  Truncated_airplane
# 134         134  e18dde99-6efd-4c6a-8fd3-343e8a393cd8.jpg  Truncated_airplane
# 132         132  dce20c6a-d661-4258-9c58-5507f38ce97e.jpg  Truncated_airplane
# 1             1  014de911-7810-4f7d-8967-3e5402209f4a.jpg  Truncated_airplane
# 86           86  9089631b-b1c0-4df8-b3f4-061c98149a94.jpg  Truncated_airplane
# 96           96  ac77b86a-4198-4d40-900e-a95e520b2ac7.jpg  Truncated_airplane
# 94           94  a9cc0c57-a46a-4d85-bd97-937cf7ffc6f8.jpg  Truncated_airplane
# 16           16  22291e0b-ebe2-4f3f-b53e-4e709179300a.jpg  Truncated_airplane
# 25           25  38ff8d64-3460-4f83-bf9c-383832aeba0d.jpg  Truncated_airplane
# 30           30  42f35cf8-66ca-400b-8381-dacc6483bb56.jpg  Truncated_airplane
# 34           34  495b73c8-024f-46cc-b426-05e49bbe5074.jpg  Truncated_airplane
# 36           36  4a0821b7-3689-4b0e-9397-389254ea9a32.jpg  Truncated_airplane
# 41           41  4e9164aa-532e-4b76-bce4-060b090da357.jpg  Truncated_airplane
# 46           46  534ba32c-cde2-402b-9b47-1396cf0999e8.jpg  Truncated_airplane
# 49           49  54b4e42b-3667-4564-b8fa-c23122ca54d5.jpg  Truncated_airplane
# 52           52  56e2d3d3-6b16-401f-a300-847272373df5.jpg  Truncated_airplane
# 58           58  58956bcc-11fc-4357-8d75-32fee9feaf07.jpg  Truncated_airplane
# 76           76  77f7b57f-5cf2-424d-a952-9847b3c3f35e.jpg  Truncated_airplane
# 79           79  78400c58-1a7c-4342-a1fb-2117cb7cbc8b.jpg  Truncated_airplane
# 84           84  8df07836-4606-446e-9880-6ed9e0f74543.jpg  Truncated_airplane
# 3             3  0263270b-e3ee-41dc-aeef-43ff77e66d5b.jpg  Truncated_airplane
# 89           89  980b5831-43b7-4adb-9e4b-67d6cff3ef68.jpg  Truncated_airplane
# 155         155  fc8f9dc5-b6a2-49f3-9bde-1f8ff382ca5f.jpg  Truncated_airplane
#
#      count
# 101     12
# 65       8
# 98       6
# 74       6
# 28       4
# 62       4
# 19       3
# 149      3
# 138      3
# 44       3
# 56       2
# 54       2
# 104      2
# 116      2
# 70       2
# 67       2
# 106      2
# 12       2
# 153      2
# 136      2
# 140      2
# 147      2
# 32       2
# 108      1
# 118      1
# 110      1
# 113      1
# 123      1
# 130      1
# 125      1
# 127      1
# 144      1
# 134      1
# 132      1
# 1        1
# 86       1
# 96       1
# 94       1
# 16       1
# 25       1
# 30       1
# 34       1
# 36       1
# 41       1
# 46       1
# 49       1
# 52       1
# 58       1
# 76       1
# 79       1
# 84       1
# 3        1
# 89       1
# 155      1

# %%
def return_truncated_airplane_info(image_id):
    """if no truncated, throw errors"""

# %%
def has_aircraft_in_given_x_y_coordinate(image_id, x_loc, y_loc):
    ## Input image_id and x, y coordinate  x (0, 2560)
    #  if the location of the image has a aircraft, return true, else return false

    """if false, return [] all other geometry contains airplane
    
    if true return image which has bounds box on entered location"""
    img = Image.open(r"/Users/lizhijie_1/Downloads/Aircraft-Detection/images/"+str(image_id))
    image = ImageDraw.Draw(img)
    
    test = plane[plane["image_id"]==image_id]
    test.reset_index(drop=True, inplace=True)

    coordinate = []
    for i in range(len(test.index)):
        tuple = (test.at[i, "Xmin"], test.at[i,"Ymin"], test.at[i, "Xmax"], test.at[i, "Ymax"])
        coordinate.append(tuple)
        if(x_loc>=tuple[0] and x_loc <= tuple[2] and 
            y_loc >= tuple[1] and y_loc <= tuple[3]):
            rect = image.rectangle(tuple, outline="red", width=5)
            img.show()
            return "Found"
        i+=1

    return "No airplane in given coordinate, here is all location that has airplanes", coordinate;

# %%
res = has_aircraft_in_given_x_y_coordinate("5c9e817a-dc4b-42ab-952c-3128e2de12e8.jpg",1600,500)
res
# Out:
# 'Found'

# %%
res1 = has_aircraft_in_given_x_y_coordinate("5c9e817a-dc4b-42ab-952c-3128e2de12e8.jpg", 2000, 1600)
res1
# Out:
# ('No airplane in given coordinate, here is all location that has airplanes',
#  [(1950, 280, 2139, 436),
#   (1990, 472, 2182, 685),
#   (1989, 722, 2187, 894),
#   (1539, 304, 1729, 453),
#   (1555, 479, 1758, 651),
#   (1572, 671, 1768, 840),
#   (1604, 868, 1789, 1018),
#   (876, 350, 1048, 482),
#   (898, 529, 1061, 668),
#   (467, 590, 643, 743),
#   (2067, 1344, 2269, 1568),
#   (2079, 1574, 2287, 1789),
#   (2090, 1806, 2293, 1978),
#   (2108, 2042, 2288, 2212),
#   (1632, 1370, 1820, 1531),
#   (1643, 1568, 1841, 1718),
#   (1664, 1739, 1841, 1889),
#   (1686, 1926, 1860, 2081),
#   (1701, 2112, 1887, 2257),
#   (958, 1445, 1137, 1601),
#   (979, 1641, 1192, 1853),
#   (993, 1901, 1207, 2057),
#   (1004, 2110, 1212, 2276),
#   (634, 2062, 724, 2137),
#   (597, 1701, 715, 1794),
#   (231, 2086, 344, 2210),
#   (48, 2072, 197, 2226),
#   (36, 1730, 122, 1836),
#   (272, 1590, 377, 1676),
#   (164, 1718, 317, 1866)])

# %%
im = Image.open(r"/Users/lizhijie_1/Downloads/Aircraft-Detection/images/5c9e817a-dc4b-42ab-952c-3128e2de12e8.jpg")
im.show()

# %%
def display_biggest_aircraft(image_id, limit_of_number):
    """if true, return list of (xmin, ymin, xmax, ymax) of all big airplane"""


    test = plane[plane["image_id"]==image_id]
    test.insert(0, "plane_size", test["width"]+test["height"])
    test1 = test.sort_values("plane_size", ascending=False)
    test1.reset_index(drop=True, inplace=True)

    img = Image.open(r"/Users/lizhijie_1/Downloads/Aircraft-Detection/images/"+str(image_id))
    image = ImageDraw.Draw(img)

    coordinate = []
    if(len(test1.index) >= limit_of_number):
        maximum = limit_of_number
    else: 
        maximum = len(test1.index)
    for i in range(maximum):
        tuple = (test1.at[i, "Xmin"], test1.at[i,"Ymin"], test1.at[i, "Xmax"], test1.at[i, "Ymax"])
        coordinate.append(tuple)
        rect = image.rectangle(tuple, outline="red", width=5)
        # print("current i = ",i)
        i+=1

    img.show()

    return coordinate;

# %%
display_biggest_aircraft("5c9e817a-dc4b-42ab-952c-3128e2de12e8.jpg",30)
# Out:
# [(2067, 1344, 2269, 1568),
#  (979, 1641, 1192, 1853),
#  (2079, 1574, 2287, 1789),
#  (1990, 472, 2182, 685),
#  (1555, 479, 1758, 651),
#  (2090, 1806, 2293, 1978),
#  (1004, 2110, 1212, 2276),
#  (1989, 722, 2187, 894),
#  (993, 1901, 1207, 2057),
#  (1572, 671, 1768, 840),
#  (2108, 2042, 2288, 2212),
#  (1632, 1370, 1820, 1531),
#  (1643, 1568, 1841, 1718),
#  (1950, 280, 2139, 436),
#  (1539, 304, 1729, 453),
#  (958, 1445, 1137, 1601),
#  (1604, 868, 1789, 1018),
#  (1701, 2112, 1887, 2257),
#  (467, 590, 643, 743),
#  (1686, 1926, 1860, 2081),
#  (1664, 1739, 1841, 1889),
#  (876, 350, 1048, 482),
#  (48, 2072, 197, 2226),
#  (898, 529, 1061, 668),
#  (164, 1718, 317, 1866),
#  (231, 2086, 344, 2210),
#  (597, 1701, 715, 1794),
#  (36, 1730, 122, 1836),
#  (272, 1590, 377, 1676),
#  (634, 2062, 724, 2137)]

# %%
def display_smallest_aircraft(image_id, limit_of_number):

    test = plane[plane["image_id"]==image_id]
    test.insert(0, "plane_size", test["width"]+test["height"])
    test1 = test.sort_values("plane_size", ascending=True)
    test1.reset_index(drop=True, inplace=True)

    img = Image.open(r"/Users/lizhijie_1/Downloads/Aircraft-Detection/images/"+str(image_id))
    image = ImageDraw.Draw(img)

    coordinate = []
    if(len(test1.index) >= limit_of_number):
        maximum = limit_of_number
    else: 
        maximum = len(test1.index)
    for i in range(maximum):
        tuple = (test1.at[i, "Xmin"], test1.at[i,"Ymin"], test1.at[i, "Xmax"], test1.at[i, "Ymax"])
        coordinate.append(tuple)
        rect = image.rectangle(tuple, outline="red", width=5)
        print("current i = ",i)
        i+=1

    img.show()

    return coordinate;

# %%
image1 = "5c9e817a-dc4b-42ab-952c-3128e2de12e8.jpg"
display_smallest_aircraft(image1, 5)
# Out:
# current i =  0
# current i =  1
# current i =  2
# current i =  3
# current i =  4
# [(634, 2062, 724, 2137),
#  (272, 1590, 377, 1676),
#  (36, 1730, 122, 1836),
#  (597, 1701, 715, 1794),
#  (231, 2086, 344, 2210)]
